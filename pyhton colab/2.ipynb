# %%
import numpy as np
import pandas as pd

df=pd.read_csv('D:/My Final Project/Meta-Python-course/train-data.csv')
df.head()
# Out:
#    Unnamed: 0                              Name    Location  Year  \
# 0           0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1           1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2           2                      Honda Jazz V     Chennai  2011
# 3           3                 Maruti Ertiga VDI     Chennai  2012
# 4           4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage   Engine  \
# 0              72000       CNG       Manual      First  26.6 km/kg   998 CC
# 1              41000    Diesel       Manual      First  19.67 kmpl  1582 CC
# 2              46000    Petrol       Manual      First   18.2 kmpl  1199 CC
# 3              87000    Diesel       Manual      First  20.77 kmpl  1248 CC
# 4              40670    Diesel    Automatic     Second   15.2 kmpl  1968 CC
#
#        Power  Seats  New_Price  Price
# 0  58.16 bhp    5.0        NaN   1.75
# 1  126.2 bhp    5.0        NaN  12.50
# 2   88.7 bhp    5.0  8.61 Lakh   4.50
# 3  88.76 bhp    7.0        NaN   6.00
# 4  140.8 bhp    5.0        NaN  17.74

# %%
df.shape
# Out:
# (6019, 14)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0              0
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine                 36
# Power                  36
# Seats                  42
# New_Price            5195
# Price                   0
# dtype: int64

# %%
df1=df.drop('New_Price')

# %%
k='18.2 kmpl'
print (k.split(''))
float(k.split(' ')[0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 2
#       1 k='18.2 kmpl'
# ----> 2 print (k.split(''))
#       3 float(k.split(' ')[0])
#
# ValueError: empty separator

# %%
def fix_units(x):
    try:
        return float(x.split(' ')[0])
    except:
        return x

# %%
df1['Mileage']=df1['Mileage'].apply(fix_units)
df1['Engine']=df1['Engine'].apply(fix_units)
df1['Power']=df1['Power'].apply(fix_units)

df1.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df1['Mileage']=df1['Mileage'].apply(fix_units)
#       2 df1['Engine']=df1['Engine'].apply(fix_units)
#       3 df1['Power']=df1['Power'].apply(fix_units)
#       4
#
# NameError: name 'df1' is not defined

# %%
df1[df1['Power'].apply(lambda x: type(x)!=float)]


df1[df1['power'].apply(lambda x: type(x)!=float)]['Power'].unique()

df1['power']=df1['power'].apply(lambda x: x.replace('null', '0') if type(x)==str else x)

df1.head()

# %%
df1['fuel_type'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df1['fuel_type'].value_counts()
#       2
#
# NameError: name 'df1' is not defined

# %%
df2.df1[df1['fuel_type']=='Petrol'].copy()

df2['']


df2['name']=df2['name'].str.lower()
df2['name']=df2['name'].str.strip()


df2['name'].value_counts()



car='maruti swift dzire vdi'
print(car.split(' '))
print(car.split(' ')[:2])
print(''.join(car.split(' ')[:2]))

df2['name']=df2['name'].apply(lambda x: ''.join(x.split(' ')[:2]))

df2.head()



car_count_more_then_10=df2['name'].value_counts()[df2['name'].value_counts()>10].index
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df2.df1[df1['fuel_type']=='Petrol'].copy()
#       2
#       3 df2['']
#       4
#
# NameError: name 'df2' is not defined

# %%
df3=df3.applymap(lambda x:np.nan if x==0 else x)


df3.groupby('fuel_Type') ['Engine'].agg(['mean','median'])

df3.groupby('Transmission') ['Engine'].agg(['mean','median'])



dfd[dfd['Engine']<141.5 | )]


s
